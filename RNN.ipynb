# %% [markdown]
# <a href="https://colab.research.google.com/github/annaqnguyen/RNNV1/blob/master/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Oct  1 03:53:08 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/chickenbestlover/RNN-Time-series-Anomaly-Detection.git
# Out:
# Cloning into 'RNN-Time-series-Anomaly-Detection'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 306 (delta 0), reused 1 (delta 0), pack-reused 303
# Receiving objects: 100% (306/306), 34.30 MiB | 32.11 MiB/s, done.
# Resolving deltas: 100% (121/121), done.

# %%
python 0_download_dataset.py
# Out:
#   File "<ipython-input-3-81297dcfa16e>", line 1
#     python 0_download_dataset.py
#             ^
# SyntaxError: invalid token

# %%
python3 0_download_dataset.py
# Out:
#   File "<ipython-input-4-fce324a9a8f1>", line 1
#     python3 0_download_dataset.py
#              ^
# SyntaxError: invalid token

# %%
# !python 0_download_dataset.py
# Out:
# python3: can't open file '0_download_dataset.py': [Errno 2] No such file or directory

# %%
# !python /content/RNN-Time-series-Anomaly-Detection/0_download_dataset.py
# Out:
# ...
# Saving to dataset/ecg/raw/ECG_data.txt
# Extracting to dataset/ecg/raw/ECG_data.zip
# ...
# Saving to dataset/ecg/raw/mitdbx_mitdbx_108.txt
# ...
# Saving to dataset/ecg/raw/qtdbsele0606.txt
# ...
# Saving to dataset/ecg/raw/chfdbchf15.txt
# ...
# Saving to dataset/ecg/raw/qtdbsel102.txt
# ...
# Saving to dataset/gesture/raw/ann_gun_CentroidA.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK16.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK17.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK14.txt
# ...
# Saving to dataset/respiration/raw/nprs44.txt
# ...
# Saving to dataset/respiration/raw/nprs43.txt
# ...
# Saving to dataset/power_demand/raw/power_data.txt
# Traceback (most recent call last):
#   File "/content/RNN-Time-series-Anomaly-Detection/0_download_dataset.py", line 182, in <module>
#     with open(str(nyc_taxi_raw_path),'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/nyc_taxi/raw/nyc_taxi.csv'

# %%
# !python3 /content/RNN-Time-series-Anomaly-Detection/0_download_dataset.py
# Out:
# ...
# Saving to dataset/ecg/raw/ECG_data.txt
# Extracting to dataset/ecg/raw/ECG_data.zip
# ...
# Saving to dataset/ecg/raw/mitdbx_mitdbx_108.txt
# ...
# Saving to dataset/ecg/raw/qtdbsele0606.txt
# ...
# Saving to dataset/ecg/raw/chfdbchf15.txt
# ...
# Saving to dataset/ecg/raw/qtdbsel102.txt
# ...
# Saving to dataset/gesture/raw/ann_gun_CentroidA.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK16.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK17.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK14.txt
# ...
# Saving to dataset/respiration/raw/nprs44.txt
# ...
# Saving to dataset/respiration/raw/nprs43.txt
# ...
# Saving to dataset/power_demand/raw/power_data.txt
# Traceback (most recent call last):
#   File "/content/RNN-Time-series-Anomaly-Detection/0_download_dataset.py", line 182, in <module>
#     with open(str(nyc_taxi_raw_path),'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/nyc_taxi/raw/nyc_taxi.csv'

# %%
# !pwd
# Out:
# /content

# %%
# !cd /content/RNN-Time-series-Anomaly-Detection

# %%
# !pwd
# Out:
# /content

# %%
# !cd /content/RNN-Time-series-Anomaly-Detection; python 0_download_dataset.py
# Out:
# ...
# Saving to dataset/ecg/raw/ECG_data.txt
# Extracting to dataset/ecg/raw/ECG_data.zip
# ...
# Saving to dataset/ecg/raw/mitdbx_mitdbx_108.txt
# ...
# Saving to dataset/ecg/raw/qtdbsele0606.txt
# ...
# Saving to dataset/ecg/raw/chfdbchf15.txt
# ...
# Saving to dataset/ecg/raw/qtdbsel102.txt
# ...
# Saving to dataset/gesture/raw/ann_gun_CentroidA.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK16.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK17.txt
# ...
# Saving to dataset/space_shuttle/raw/TEK14.txt
# ...
# Saving to dataset/respiration/raw/nprs44.txt
# ...
# Saving to dataset/respiration/raw/nprs43.txt
# ...
# Saving to dataset/power_demand/raw/power_data.txt

# %%
# !cd /content/RNN-Time-series-Anomaly-Detection; python 1_train_predictor.py --data ecg --filename chfdb_chf13_45590.pkl --save_fig
# Out:
# => Start training from scratch
# -----------------------------------------------------------------------------------------
# Namespace(augment=True, batch_size=64, bptt=50, clip=10, data='ecg', device='cuda', dropout=0.2, emsize=32, epochs=400, eval_batch_size=64, filename='chfdb_chf13_45590.pkl', log_interval=10, lr=0.0002, model='LSTM', nhid=32, nlayers=2, prediction_window_size=10, pretrained=False, res_connection=False, resume=False, save_fig=True, save_interval=10, seed=1111, teacher_forcing_ratio=0.7, tied=False, weight_decay=0.0001)
# -----------------------------------------------------------------------------------------
# | epoch   1 |    10/   31 batches | ms/batch 84.4532 | loss  2.21
# | epoch   1 |    20/   31 batches | ms/batch 74.8522 | loss  2.01
# | epoch   1 |    30/   31 batches | ms/batch 75.9683 | loss  1.99
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  3.08s | valid loss 3.2264 |
# ...

# %%
# !cd /content/RNN-Time-series-Anomaly-Detection; python 2_anomaly_detection.py --data ecg --filename chfdb_chf13_45590.pkl --prediction_window 10 --save_fig
# Out:
# -----------------------------------------------------------------------------------------
# => loading checkpoint
# => loaded checkpoint
# => loading pre-calculated mean and covariance
# => calculating anomaly scores
# => calculating precision, recall, and f_beta
# /content/RNN-Time-series-Anomaly-Detection/anomalyDetector.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   th = torch.logspace(0, torch.log10(torch.tensor(maximum)), num_samples).to(args.device)
# data:  ecg  filename:  chfdb_chf13_45590.pkl  f-beta (no compensation):  0.48056530952453613  beta:  1.0
# => loading pre-calculated mean and covariance
# => calculating anomaly scores
# => calculating precision, recall, and f_beta
# ...

# %%
# !cd /content/RNN-Time-series-Anomaly-Detection; python png2gif.py

# %%
# !pip install imageio
